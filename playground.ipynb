# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.cm import gnuplot, jet

# %matplotlib notebook

# %%
df = pd.read_csv('V735_N2_4e13GeVpr_150_1_reSpect(1e-2).LDLTS', delimiter = '\t')
columns = np.asarray(df.columns)
columns[0] = 'Temperature'
df.columns = columns
df
# Out:
#      Temperature  1.000000E+02  9.111628E+01  8.302176E+01  7.564633E+01  \
# 0         105.86  2.474743e-32  1.392490e-31  7.835917e-31  4.410537e-30
# 1         105.99  5.954051e-29  1.344243e-28  3.035748e-28  6.861461e-28
# 2         106.28  4.432954e-27  8.564158e-27  1.654959e-26  3.200510e-26
# 3         106.61  2.727401e-04  1.981756e-04  1.441196e-04  1.051052e-04
# 4         107.04  4.704818e-20  1.766587e-19  6.633398e-19  2.490935e-18
# ..           ...           ...           ...           ...           ...
# 506       410.23  2.012703e-02  1.720277e-02  1.470489e-02  1.257454e-02
# 507       410.79  1.977641e-02  1.699569e-02  1.460728e-02  1.255870e-02
# 508       411.40  1.812115e-02  1.571437e-02  1.362839e-02  1.182301e-02
# 509       412.06  1.949796e-02  1.680224e-02  1.448041e-02  1.248327e-02
# 510       412.67  1.599921e-02  1.410918e-02  1.244315e-02  1.097624e-02
#
#      6.892612E+01  6.280291E+01  5.722368E+01  5.214008E+01  4.750810E+01  \
# ...

# %%
fig = plt.figure(figsize = (9,4))
ax  = fig.add_subplot()

color = np.linspace(0, 1, len(columns) - 1)
color = gnuplot(color)

for i, c in enumerate(columns[1:]):
    if i%10 == 0:
        ax.plot(df['Temperature'], df[c]/max(df[c]), c = color[i],
                label = r'$\tau$ = %.2f s'%(float(c)), lw = 3)
ax.legend()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="900">
