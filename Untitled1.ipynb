# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.append('functions/')
from ilt import SVD
from read_file import read_file


#from read_file import read_file
#from interface import interface

# %matplotlib notebook
plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

# %%
t, C, T = read_file('/Users/antonvasilev/Google Drive/04cryo/2020 november/#2/Proton&neutron(200um)diode_150_1.DLTS')

# %%
#t = np.arange(0.15, 15, 0.15)
#C = 2*np.exp(-1*t) + 3*np.exp(-8*t)+3
#C = C + 0.0001*t
#C = C + np.random.normal(0, 1, len(t))*5e-2
#p = np.zeros(len(t))
#p[int(len(t)/2)] = C[int(len(t)/2)]*0.3
#p[int(len(t)/10)] = -C[int(len(t)/10)]*0.2
#C = C + p
#plt.plot(t, C)
#plt.plot(t, adv_average(C, 1))

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
#ax.set_xscale('log')

x = [299, 301, 303, 330, 336, 337, 341, 343, 346, 365, 366, ]

for _C in C[x]:
    ax.plot(t, _C)
print(T[x])
    #z, f, C_r = SVD(t, C[i] - C[i][-1], [1e-2, 1e2], 100, 0.1)
    #ax.plot(1/z, f)
# Out:
# <img src="data:image/png;base64,..." width="432">
# [315.91 317.09 318.31 334.43 338.03 338.65 341.05 342.24 344.01 355.32
#  355.89]
